# %% [markdown]
# ## SA Using LSTM and Flask Deployment - AI University

# %%
# !pip install numpy==1.16.1

# %%
import numpy
from numpy import array
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, Dropout
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.models import load_model
import re
import numpy as np
import nltk
from nltk.tokenize import word_tokenize

# %%
numpy.random.seed(7)

# %%
# load the dataset 
# vocabulary size = 5000
vocab = 5000 # vocab size
(X_train,y_train), (X_test,y_test) = imdb.load_data(num_words=vocab)

# %%
# we use the dictionary returned by imbd.get_word_index() to map the review back to original

word2id = imdb.get_word_index()
id2word = {i: word for word, i in word2id.items()}
print('------review with words-----')
print([id2word.get(i,' ') for i in X_train[4]])
print('-------LABEL--------')
print(y_train[4])

# %%
# maximum review length
print('Maximum review length: {}'.format(len(max((X_train + X_test),key=len))))

#  minimum review length
print('Minimum review length: {}'.format(len(min((X_train + X_test),key=len))))

# %%
## Pad the data
max_review_length = 500
X_train = sequence.pad_sequences(X_train,maxlen=max_review_length)
X_test = sequence.pad_sequences(X_test,maxlen=max_review_length)

# %%
## Build LSTM Model

embedding_vector_length = 32
model = Sequential()
model.add(Embedding(top_words,embedding_vector_length,input_length=max_review_length))
model.add(Dropout(0.4))
model.add(LSTM(100))
model.add(Dropout(0.4))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
print(model.summary())
model.fit(X_train,y_train, validation_data=(X_test,y_test),epochs=30, batch_size=64)

# %%
scores = model.evaluate(X_test,y_test,verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))

# %%
# Save the model
model.save('sentiment_analysis_model.h5')
print("Saved model")
